# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\MEGHANA VASIREDDI\Documents\naresh it\dataset\visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include="object").columns
num_columns=visa_df.select_dtypes(exclude="object").columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
wage=visa_df["prevailing_wage"]
plt.boxplot(wage)
plt.show()

# %%
plt.boxplot(wage,vert=False)
plt.show()

# %%
plt.boxplot(wage,vert=False)
plt.title("Boxplot")
plt.show()

# %%
sns.boxplot(wage,orient="h")
plt.title("Boxplot")
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
plt.hist(wage)
plt.title("histogram")
plt.xlabel("prevaling_wage")
plt.ylabel("count")
plt.subplot(1,2,2)
plt.boxplot(wage,vert=False)
plt.xlabel("prevaling_wage")
plt.title("Boxplot")
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,1).hist(wage)
plt.subplot(1,2,2).boxplot(wage,vert=False)
plt.show()

# %% [markdown]
# **finding the outliers**

# %%
q1=np.percentile(wage,25)
q2=np.percentile(wage,50)
q3=np.percentile(wage,75)
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR
con1=wage<lb
con2=wage>ub
con3=con1 | con2
wage[con3]
# Out:
# 14       220081.73
# 34       225569.73
# 130      247393.01
# 216      269321.68
# 221      219529.62
#            ...
# 25191    280482.51
# 25195    234308.77
# 25468    272715.74
# 25469    273772.47
# 25476    279174.79
# Name: prevailing_wage, Length: 427, dtype: float64

# %%
q1=np.percentile(wage,25)
q2=np.percentile(wage,50)
q3=np.percentile(wage,75)
IQR=q3-q1
lb=q1-1.5*IQR
ub=q3+1.5*IQR
con1=wage>lb
con2=wage<ub
con3=con1 & con2
non_outlier_wage=visa_df[con3]
non_outlier_wage
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
wage_non_outliers=non_outlier_wage["prevailing_wage"]
plt.figure(figsize=(14,5)) 
plt.subplot(1,2,1).hist(wage_non_outliers)
plt.subplot(1,2,2).boxplot(wage_non_outliers,vert=False)
plt.show()

# %%
plt.figure(figsize=(14,8))
plt.subplot(2,2,1).hist(wage)
plt.subplot(2,2,2).boxplot(wage,vert=False)
plt.subplot(2,2,3).hist(wage_non_outliers)
plt.subplot(2,2,4).boxplot(wage_non_outliers,vert=False)
plt.show()

# %%
wage_median=visa_df["prevailing_wage"].median()
wage_median
# Out:
# np.float64(70308.20999999999)

# %%
plt.figure(figsize=(14,8))
plt.hist(wage)
plt.hist(wage_non_outliers)
plt.show()

# %% [markdown]
# **how to deal the outliers**

# %% [markdown]
# - 1. we can drop the outliers
#
#
#     - droping outilers is easy task but not recommaned
#
#     - if you drop the outliers we are droping the rows
#
#     - which means we droping the other column values also
#
#     - may be some important information we might loose from other columnn values
#
#     - but in industry if outliers percentagr less than 2% of the total data , we can drop
#
#     - the number of outliers in pwage is 427
#
#     - the percentage is 1.67 which is lwssthan 2%
#
# - 2. fill with median value
#
#
#     - we arleady know that outliers does not affect by median
#
#     - so it is best practice to fill the outliers with median
#
# - 3. capping or flooring
#
#
#     - instead of fill with median
#
#     - we can fill with certian values
#
#     - the outliers which are less than LB fill with LB value
#
#     - the outliers which are greater than UB fill with UB value
#
# - **isolation forest**
#
#     - is ML model used to find the outliers and anamolies

# %% [markdown]
# **filled with median value**

# %% [markdown]
# **np.where**

# %% [markdown]
# - in numpy we have method called where
#
# - it takes three arguments
#
#     - 1. condition
#
#     - 2. value if condition is True
#
#     - 3. value if condition is false
#
# - it is applicable for only binary means if and else

# %%
for value in wage:
    print(value)
# Out:
# 592.2029
# 83425.65
# 122996.86
# 83434.03
# 149907.39
# 78252.14
# 53635.39
# 418.2298
# 74362.19
# 67514.76
# 83588.56
# 70813.09
# 28663.05
# 107196.03
# 220081.73
# 74108.02
# 3706.79
# 16132.61
# 150441.13
# 79948.12
# 71128.98
# 137694.98
# 45642.39
# 90108.38
# 71286.04
# 99489.65
# 86332.95
# 103029.33
# 40925.86
# 189190.48
# 79594.12
# 135866.13
# 72077.57
# 81921.18
# 225569.73
# 92421.92
# 2490.12
# 110817.26
# 50960.01
# 125336.9
# 39633.32
# 156326.33
# 43630.58
# 54614.42
# 28989.87
# 22924.91
# 61567.75
# 156251.17
# 86022.02
# 49565.37
# 66191.41
# 95623.2
# 115014.05
# 35018.04
# 230.8072
# 113799.64
# 85854.09
# 14174.04
# 47176.84
# 4949.28
# 67410.59
# 58791.58
# 103.2216
# 62591.57
# 102919.59
# 123468.56
# 82324.64
# 5319.49
# 153019.94
# 38059.89
# 230.327
# 61521.92
# 121316.5
# 122540.55
# 47170.76
# 330.3743
# 2927.34
# 107781.48
# 590.0203
# 194176.83
# 102073.81
# 113882.38
# 70778.82
# 84125.48
# 174014.59
# 34213.17
# 79813.05
# 113327.34
# 78893.64
# ...

# %%
list1=[]
for value in wage:
    if value < lb or value > ub:
        median=wage.median()
        list1.append(median)
    else:
        list1.append(value)
list1
# Out:
# [592.2029,
#  83425.65,
#  122996.86,
#  83434.03,
#  149907.39,
#  78252.14,
#  53635.39,
#  418.2298,
#  74362.19,
#  67514.76,
#  83588.56,
#  70813.09,
#  28663.05,
#  107196.03,
#  np.float64(70308.20999999999),
#  74108.02,
#  3706.79,
#  16132.61,
#  150441.13,
#  79948.12,
#  71128.98,
#  137694.98,
#  45642.39,
#  90108.38,
#  71286.04,
#  99489.65,
#  86332.95,
#  103029.33,
#  40925.86,
#  189190.48,
#  79594.12,
#  135866.13,
#  72077.57,
#  81921.18,
#  np.float64(70308.20999999999),
#  92421.92,
#  2490.12,
#  110817.26,
#  50960.01,
#  125336.9,
#  39633.32,
#  156326.33,
#  43630.58,
#  54614.42,
#  28989.87,
#  22924.91,
#  61567.75,
#  156251.17,
#  86022.02,
#  49565.37,
#  66191.41,
#  95623.2,
#  115014.05,
#  35018.04,
#  230.8072,
#  113799.64,
#  85854.09,
#  14174.04,
#  47176.84,
#  4949.28,
#  67410.59,
#  58791.58,
#  103.2216,
#  62591.57,
#  102919.59,
#  123468.56,
#  82324.64,
#  5319.49,
#  153019.94,
#  38059.89,
#  230.327,
#  61521.92,
# ...

# %%
dict1={"sub":["ds","de","cs"],"marks":[100,200,300]}
df=pd.DataFrame(dict1)
df
# Out:
#   sub  marks
# 0  ds    100
# 1  de    200
# 2  cs    300

# %%
l=[]
for i in df.marks:
    if i > 100:
        l.append(1)
    else:
        l.append(i)
df["new"]=l
df
# Out:
#   sub  marks  new
# 0  ds    100  100
# 1  de    200    1
# 2  cs    300    1

# %%
dict1={"sub":["ds","de","cs"],"marks":[100,200,300]}
df=pd.DataFrame(dict1)
l=[]
for i in df.marks:
    if i > 100:
        l.append(1)
    else:
        l.append(i)
df["marks"]=l
df
# Out:
#   sub  marks
# 0  ds    100
# 1  de      1
# 2  cs      1

# %%
dict1={"sub":["ds","de","cs"],"marks":[100,200,300]}
df1=pd.DataFrame(dict1)
df1
# Out:
#   sub  marks
# 0  ds    100
# 1  de    200
# 2  cs    300

# %%
#np.where(<condition>,<True><False>)
con=df1["marks"]>100
l=np.where(con,l,df1["marks"])
df1["marks"]=l
df1
# Out:
#   sub  marks
# 0  ds    100
# 1  de      1
# 2  cs      1

# %%
# implement for the outliers 
con1=wage<lb
con2=wage>ub
con=con1|con2
wage_median=wage.median()
l=np.where(con,wage_median,wage)
l
# Out:
# array([   592.2029,  83425.65  , 122996.86  , ..., 146298.85  ,
#         86154.77  ,  70876.91  ])

# %%
visa_df["prevailing_wage_update"]=l

# %%
plt.subplot(1,2,1).boxplot(visa_df["prevailing_wage_update"])
plt.subplot(1,2,2).hist(visa_df["prevailing_wage_update"])
# Out:
# (array([4580., 3368., 3890., 4369., 3507., 2860., 1643.,  706.,  295.,
#          262.]),
#  array([2.13670000e+00, 2.18113840e+04, 4.36206314e+04, 6.54298787e+04,
#         8.72391260e+04, 1.09048373e+05, 1.30857621e+05, 1.52666868e+05,
#         1.74476115e+05, 1.96285363e+05, 2.18094610e+05]),
#  <BarContainer object of 10 artists>)
